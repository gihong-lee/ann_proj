# %%
import time
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras as keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, Input, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications import VGG16

# %%
import os
import tensorflow as tf

#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# GPU found

# %%
data = pd.read_csv('emnist-byclass-mapping.txt', sep=" ", header=None)
data.columns = ['Target','ASCII']

col=[]
for i in data.ASCII.tolist():
    col.append(chr(i))

data['ASCII_Target'] = pd.Series(col)

# %%
train_df = pd.read_csv('emnist-byclass-train.csv')
train_df.rename(columns={'35':'Target'}, inplace=True)
train_y = np.array(train_df.pop('Target'))
train_x = train_df

train_x = train_x / 255.0
train_x = train_x.values.reshape([-1, 28, 28, 1])
train_y = keras.utils.to_categorical(train_y)

train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# %%
test_df = pd.read_csv('emnist-byclass-test.csv')
test_df.rename(columns={'18':'Target'}, inplace=True)

# test_df=pd.merge(test_df, data, how='left', on='Target')
# test_df=test_df.drop(['Target','ASCII'],axis=1)
# test_df.rename(columns={'ASCII_Target':'Target'}, inplace=True)

test_y = np.array(test_df.pop('Target'))
test_x = test_df

test_x = test_x / 255.0
test_x = test_x.values.reshape([-1, 28, 28, 1])
test_y = keras.utils.to_categorical(test_y)

# %%
def data_crop(data, mean):
  # images = np.zeros((data.shape[0], 20, 20))
  for i in range(data.shape[0]):
    image = data[i]
    first_norm = 255/np.max(image)
    image = (image*first_norm).astype(np.uint8)

    _, binary_image = cv2.threshold(image.astype(np.uint8), 20, 255, cv2.THRESH_BINARY)
    min_max_list = np.where(binary_image==255)
    x_min, x_max = np.min(min_max_list[1]), np.max(min_max_list[1])
    y_min, y_max = np.min(min_max_list[0]), np.max(min_max_list[0])

    if abs(x_max - x_min) >abs(y_max - y_min):
      add_sub_factor = (abs(x_max - x_min) - abs(y_max - y_min))//2
      y_min = max(0, y_min-add_sub_factor-1)
      y_max = min(27, y_max+add_sub_factor+1)

    if abs(y_max - y_min) > abs(x_max - x_min):
      add_sub_factor = (abs(y_max - y_min)-abs(x_max - x_min))//2
      x_min = max(0, x_min-add_sub_factor-1)
      x_max = min(27, x_max+add_sub_factor+1)
    # print(x_min, x_max)
    # print(y_min, y_max)
    data[i] = np.pad(cv2.resize(image.astype(np.uint8)[y_min:y_max, x_min:x_max], (20, 20)), ((4, 4), (4, 4)), 'constant', constant_values = 0)
    second_norm = 255/np.max(data[i])
    data[i] = (data[i]*second_norm).astype(np.uint8)

# %%
hand_df = pd.read_csv('our_handmade_dataset.csv')
hand_df.rename(columns={'0':'Target'}, inplace=True)

# hand_df=pd.merge(hand_df, data, how='left', on='Target')
# hand_df=hand_df.drop(['Target','ASCII'],axis=1)
# hand_df.rename(columns={'ASCII_Target':'Target'}, inplace=True)

hand_y = np.array(hand_df.pop('Target'))
hand_x = hand_df

hand_x = hand_x / 255.0
hand_x = hand_x.values.reshape([-1, 28, 28, 1])
hand_y = keras.utils.to_categorical(hand_y)

# %%
inputs = Input(shape = (28,28,1))
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(inputs)
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 2nd Conv Block
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 3rd Conv block  
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 4th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 5th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# Fully connected layers  
x = Flatten()(x)
x= BatchNormalization()(x)
x = Dense(units = 4096, activation ='relu')(x)
x = Dense(units = 4096, activation ='relu')(x)
output = Dense(units = 62, activation ='softmax')(x)
# creating the model

new_emnist_model = Model (inputs=inputs, outputs =output)
new_emnist_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 32)        320
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_14 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 64)        18496
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_15 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 128)         73856
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 128)         147584
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_16 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 256)         295168
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 256)         590080
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_17 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_37 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_18 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 2, 2, 256)         0
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  batch_normalization_19 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_6 (Dense)             (None, 4096)              1052672
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dense_8 (Dense)             (None, 62)                254014
#
# =================================================================
# Total params: 21,771,550
# Trainable params: 21,769,566
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
new_emnist_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.005), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("my_new_emnist_model.h5", save_best_only=True)
  
new_emnist_model.fit(train_x, train_y, batch_size = 32, epochs=100, validation_data=(val_x, val_y), callbacks=[early_stopping_cb, model_checkpoint_cb])

new_emnist_model.evaluate(test_x, test_y)
# Out:
# Epoch 1/100
# 17449/17449 [==============================] - 255s 15ms/step - loss: 0.8217 - accuracy: 0.7476 - val_loss: 1.0900 - val_accuracy: 0.8230
# Epoch 2/100
# 17449/17449 [==============================] - 252s 14ms/step - loss: 0.4873 - accuracy: 0.8395 - val_loss: 0.9377 - val_accuracy: 0.8372
# Epoch 3/100
# 17449/17449 [==============================] - 250s 14ms/step - loss: 0.4507 - accuracy: 0.8497 - val_loss: 209.7614 - val_accuracy: 0.8493
# Epoch 4/100
# 17449/17449 [==============================] - 252s 14ms/step - loss: 0.4316 - accuracy: 0.8556 - val_loss: 12520.9385 - val_accuracy: 0.8535
# Epoch 5/100
# 17449/17449 [==============================] - 254s 15ms/step - loss: 0.4193 - accuracy: 0.8591 - val_loss: 0.4477 - val_accuracy: 0.8547
# Epoch 6/100
# 17449/17449 [==============================] - 251s 14ms/step - loss: 0.4121 - accuracy: 0.8610 - val_loss: 0.4918 - val_accuracy: 0.8450
# Epoch 7/100
# 17449/17449 [==============================] - 249s 14ms/step - loss: 0.4046 - accuracy: 0.8635 - val_loss: 0.4548 - val_accuracy: 0.8572
# Epoch 8/100
# 17449/17449 [==============================] - 249s 14ms/step - loss: 0.3977 - accuracy: 0.8649 - val_loss: 0.7532 - val_accuracy: 0.8527
# Epoch 9/100
# 17449/17449 [==============================] - 249s 14ms/step - loss: 0.3929 - accuracy: 0.8661 - val_loss: 5.1233 - val_accuracy: 0.8588
# Epoch 10/100
# 17449/17449 [==============================] - 250s 14ms/step - loss: 0.3903 - accuracy: 0.8676 - val_loss: 1.4128 - val_accuracy: 0.8565
# Epoch 11/100
# 17449/17449 [==============================] - 251s 14ms/step - loss: 0.3879 - accuracy: 0.8679 - val_loss: 1.2814 - val_accuracy: 0.8471
# Epoch 12/100
# 17449/17449 [==============================] - 251s 14ms/step - loss: 0.3831 - accuracy: 0.8689 - val_loss: 0.5346 - val_accuracy: 0.8441
# Epoch 13/100
# 17449/17449 [==============================] - 251s 14ms/step - loss: 0.3811 - accuracy: 0.8695 - val_loss: 0.4713 - val_accuracy: 0.8540
# Epoch 14/100
# 17449/17449 [==============================] - 251s 14ms/step - loss: 0.3802 - accuracy: 0.8703 - val_loss: 6.2359 - val_accuracy: 0.8576
# Epoch 15/100
# 17449/17449 [==============================] - 250s 14ms/step - loss: 0.3789 - accuracy: 0.8706 - val_loss: 1.2997 - val_accuracy: 0.8519
# 3636/3636 [==============================] - 16s 4ms/step - loss: 0.4430 - accuracy: 0.8570
# [0.44302284717559814, 0.8570089936256409]

# %%
new_emnist_model.evaluate(hand_x, hand_y)
# Out:
# 78/78 [==============================] - 0s 6ms/step - loss: 220.3492 - accuracy: 0.3167
# [220.34922790527344, 0.31665995717048645]

# %%
inputs = Input(shape = (28,28,1))
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(inputs)
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 2nd Conv Block
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 3rd Conv block  
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 4th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 5th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# Fully connected layers  
x = Flatten()(x)
x= BatchNormalization()(x)
x = Dense(units = 4096, activation ='relu')(x)
x = Dense(units = 4096, activation ='relu')(x)
output = Dense(units = 62, activation ='softmax')(x)
# creating the model

nnew_emnist_model = Model (inputs=inputs, outputs =output)
nnew_emnist_model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_52 (Conv2D)          (None, 28, 28, 32)        320
#
#  conv2d_53 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_20 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 14, 14, 64)        18496
#
#  conv2d_55 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_21 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 14, 14, 64)        0
#
#  max_pooling2d_21 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 128)         73856
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 128)         147584
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_22 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 7, 7, 128)         0
#
#  max_pooling2d_22 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_59 (Conv2D)          (None, 4, 4, 256)         295168
#
#  conv2d_60 (Conv2D)          (None, 4, 4, 256)         590080
#
#  conv2d_61 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_23 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 4, 4, 256)         0
#
#  max_pooling2d_23 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_63 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_64 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_24 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 2, 2, 256)         0
#
#  max_pooling2d_24 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  batch_normalization_25 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_12 (Dense)            (None, 4096)              1052672
#
#  dense_13 (Dense)            (None, 4096)              16781312
#
#  dense_14 (Dense)            (None, 62)                254014
#
# =================================================================
# Total params: 21,771,550
# Trainable params: 21,769,566
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
nnew_emnist_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.005), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("my_new_emnist_model.h5", save_best_only=True)
  
nnew_emnist_model.fit(train_x, train_y, batch_size = 32, epochs=100, validation_data=(val_x, val_y), callbacks=[early_stopping_cb, model_checkpoint_cb])

nnew_emnist_model.evaluate(test_x, test_y)
# Out:
# Epoch 1/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.9405 - accuracy: 0.7170 - val_loss: 2.2228 - val_accuracy: 0.8020
# Epoch 2/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.5000 - accuracy: 0.8348 - val_loss: 0.5747 - val_accuracy: 0.8366
# Epoch 3/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.4625 - accuracy: 0.8444 - val_loss: 157.2600 - val_accuracy: 0.8477
# Epoch 4/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.4405 - accuracy: 0.8510 - val_loss: 0.6730 - val_accuracy: 0.8494
# Epoch 5/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.4269 - accuracy: 0.8552 - val_loss: 4.8108 - val_accuracy: 0.8548
# Epoch 6/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.4179 - accuracy: 0.8577 - val_loss: 0.4772 - val_accuracy: 0.8420
# Epoch 7/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.4089 - accuracy: 0.8606 - val_loss: 0.5357 - val_accuracy: 0.8609
# Epoch 8/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.4034 - accuracy: 0.8624 - val_loss: 0.4662 - val_accuracy: 0.8439
# Epoch 9/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3993 - accuracy: 0.8632 - val_loss: 7703.5088 - val_accuracy: 0.8533
# Epoch 10/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3957 - accuracy: 0.8639 - val_loss: 0.4162 - val_accuracy: 0.8604
# Epoch 11/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3904 - accuracy: 0.8658 - val_loss: 2.4672 - val_accuracy: 0.8627
# Epoch 12/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3876 - accuracy: 0.8665 - val_loss: 1.2809 - val_accuracy: 0.8586
# Epoch 13/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3855 - accuracy: 0.8669 - val_loss: 0.6075 - val_accuracy: 0.8572
# Epoch 14/100
# 17449/17449 [==============================] - 271s 16ms/step - loss: 0.3849 - accuracy: 0.8673 - val_loss: 8.8596 - val_accuracy: 0.8615
# Epoch 15/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.3790 - accuracy: 0.8688 - val_loss: 3.2545 - val_accuracy: 0.8554
# Epoch 16/100
# 17449/17449 [==============================] - 271s 16ms/step - loss: 0.3793 - accuracy: 0.8691 - val_loss: 0.6998 - val_accuracy: 0.8484
# Epoch 17/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3771 - accuracy: 0.8695 - val_loss: 1.5513 - val_accuracy: 0.8589
# Epoch 18/100
# 17449/17449 [==============================] - 272s 16ms/step - loss: 0.3754 - accuracy: 0.8700 - val_loss: 11.5225 - val_accuracy: 0.7594
# Epoch 19/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.3735 - accuracy: 0.8710 - val_loss: 0.9471 - val_accuracy: 0.7759
# Epoch 20/100
# 17449/17449 [==============================] - 273s 16ms/step - loss: 0.3732 - accuracy: 0.8710 - val_loss: 2.7491 - val_accuracy: 0.8614
# 3636/3636 [==============================] - 16s 4ms/step - loss: 0.4112 - accuracy: 0.8620
# [0.4111975431442261, 0.8620467185974121]

# %%
nnew_emnist_model.evaluate(hand_x, hand_y)
# Out:
# 78/78 [==============================] - 0s 5ms/step - loss: 4.9798 - accuracy: 0.2997
# [4.979769706726074, 0.29971763491630554]

# %%
inputs = Input(shape = (28,28,1))
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(inputs)
x = Conv2D (filters =32, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 2nd Conv Block
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 3rd Conv block  
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x) 
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 4th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# 5th Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x= BatchNormalization()(x)
x= Dropout(0.3)(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
# Fully connected layers  
x = Flatten()(x)
x= BatchNormalization()(x)
x = Dense(units = 4096, activation ='relu')(x)
x = Dense(units = 4096, activation ='relu')(x)
output = Dense(units = 62, activation ='softmax')(x)
# creating the model

nnnew_emnist_model = Model (inputs=inputs, outputs =output)
nnnew_emnist_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 32)        320
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_6 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 64)        18496
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 128)         73856
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 128)         147584
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_8 (Batc  (None, 7, 7, 128)        512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 256)         295168
#
#  conv2d_21 (Conv2D)          (None, 4, 4, 256)         590080
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_24 (Conv2D)          (None, 2, 2, 256)         590080
#
#  conv2d_25 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_10 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 2, 256)         0
#
#  max_pooling2d_9 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_3 (Dense)             (None, 4096)              1052672
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dense_5 (Dense)             (None, 62)                254014
#
# =================================================================
# Total params: 21,771,550
# Trainable params: 21,769,566
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
nnnew_emnist_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("my_new_emnist_model.h5", save_best_only=True)
  
nnnew_emnist_model.fit(train_x, train_y, batch_size = 64, epochs=100, validation_data=(val_x, val_y), callbacks=[early_stopping_cb, model_checkpoint_cb])

nnnew_emnist_model.evaluate(test_x, test_y)
# Out:
# Epoch 1/100
# 8725/8725 [==============================] - 143s 16ms/step - loss: 1.1460 - accuracy: 0.6782 - val_loss: 1.1137 - val_accuracy: 0.7943
# Epoch 2/100
# 8725/8725 [==============================] - 137s 16ms/step - loss: 0.5294 - accuracy: 0.8267 - val_loss: 0.5072 - val_accuracy: 0.8321
# Epoch 3/100
# 8725/8725 [==============================] - 138s 16ms/step - loss: 0.4860 - accuracy: 0.8399 - val_loss: 865.9083 - val_accuracy: 0.8369
# Epoch 4/100
# 8725/8725 [==============================] - 143s 16ms/step - loss: 0.4594 - accuracy: 0.8471 - val_loss: 24895.3848 - val_accuracy: 0.8423
# Epoch 5/100
# 8725/8725 [==============================] - 145s 17ms/step - loss: 0.4453 - accuracy: 0.8517 - val_loss: 255.8235 - val_accuracy: 0.8354
# Epoch 6/100
# 4819/8725 [===============>..............] - ETA: 3:05 - loss: 0.4382 - accuracy: 0.8534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\4DTRAV~1\AppData\Local\Temp/ipykernel_16072/1639882233.py in <module>
#       4 model_checkpoint_cb = keras.callbacks.ModelCheckpoint("my_new_emnist_model.h5", save_best_only=True)
#       5
# ----> 6 nnnew_emnist_model.fit(train_x, train_y, batch_size = 64, epochs=100, validation_data=(val_x, val_y), callbacks=[early_stopping_cb, model_checkpoint_cb])
#       7
#       8 nnnew_emnist_model.evaluate(test_x, test_y)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
nnnew_emnist_model.evaluate(hand_x, hand_y)
